# %%
import pandas as pd
pd.read_csv("data/Clean_Pitching_Data.csv")
# Out:
#       Unnamed: 0   playerID  yearID teamID   W   L   G  GS  CG  SHO  IPouts  \
# 0              0  bechtge01    1871    PH1   1   2   3   3   2    0    78.0
# 1              1  brainas01    1871    WS3  12  15  30  30  30    0   792.0
# 2              3  fishech01    1871    RC1   4  16  24  24  22    1   639.0
# 3              4  fleetfr01    1871    NY2   0   1   1   1   1    0    27.0
# 4              7  mathebo01    1871    FW1   6  11  19  19  19    1   507.0
# ...          ...        ...     ...    ...  ..  ..  ..  ..  ..  ...     ...
# 7457       44111  wielajo01    2015    LAN   0   1   2   2   0    0    26.0
# 7458       44116  wilsocj01    2015    LAA   8   8  21  21   0    0   396.0
# 7459       44124   woodal02    2015    ATL   7   6  20  20   0    0   358.0
# 7460       44125   woodal02    2015    LAN   5   6  12  12   0    0   211.0
# 7461       44136  zimmejo02    2015    WAS  13  10  33  33   0    0   605.0
#
#         ERA
# 0      7.96
# 1      4.50
# 2      4.35
# ...

# %%
Cpitch = pd.read_csv("data/Clean_Pitching_Data.csv", encoding= 'utf-8')
Cpitch.tail(10)
# Out:
#       Unnamed: 0   playerID  yearID teamID   W   L   G  GS  CG  SHO  IPouts  \
# 7452       44098  wagnety01    2015    MIL   0   2   3   3   0    0    41.0
# 7453       44101  walketa01    2015    SEA  11   8  29  29   1    0   509.0
# 7454       44104  weaveje02    2015    LAA   7  12  26  26   1    1   477.0
# 7455       44107  weberry01    2015    ATL   0   3   5   5   0    0    85.0
# 7456       44110  whitlch01    2015    NYA   1   2   4   4   0    0    58.0
# 7457       44111  wielajo01    2015    LAN   0   1   2   2   0    0    26.0
# 7458       44116  wilsocj01    2015    LAA   8   8  21  21   0    0   396.0
# 7459       44124   woodal02    2015    ATL   7   6  20  20   0    0   358.0
# 7460       44125   woodal02    2015    LAN   5   6  12  12   0    0   211.0
# 7461       44136  zimmejo02    2015    WAS  13  10  33  33   0    0   605.0
#
#        ERA
# 7452  7.24
# 7453  4.56
# 7454  4.64
# 7455  4.76
# 7456  4.19
# 7457  8.31
# 7458  3.89
# 7459  3.54
# 7460  4.35
# ...

# %%
CGchart = print(Cpitch.plot(x='yearID', y='CG', kind = "line"))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
GChart = print(Cpitch.plot(x = 'yearID', y = 'G', kind = 'line'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
Cpitch.plot(x = 'yearID', y = 'G', marker='', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
Cpitch.plot(x = 'yearID', y = 'CG',  marker='', color='olive', linewidth=2)

# %%
Cpitch.mean(axis = 0,)
# Out:
# Unnamed: 0    24492.167783
# yearID         1971.753149
# W                 7.326320
# L                 6.651434
# G                18.208255
# GS               18.208255
# CG                4.242026
# SHO               0.694854
# IPouts          362.411686
# ERA               5.009437
# dtype: float64
